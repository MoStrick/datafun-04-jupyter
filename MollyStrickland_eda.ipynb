# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import jupyterlab

# %% [markdown]
# ### 4. Exploratory Data Analysis

# %% [markdown]
# ### Step 1: Data Aquisition

# %%
# Load the Iris dataset into DataFrame
df = sns.load_dataset('iris')

# Inspect first rows of the DataFrame
print(df.head())

# Load the 'titanic' dataset
df_titanic = sns.load_dataset('titanic')
print("\nFirst 5 rows of the 'titanic' dataset:")
print(df_titanic.head())

# Load the 'penguins' dataset
df_penguins = sns.load_dataset('penguins')
print("\nFirst 5 rows of the 'penguins' dataset:")
print(df_penguins.head())

# Load the 'diamonds' dataset
df_diamonds = sns.load_dataset('diamonds')
print("\nFirst 5 rows of the 'diamonds' dataset:")
print(df_diamonds.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# First 5 rows of the 'titanic' dataset:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns

# List all available datasets
datasets = sns.get_dataset_names()
print("Available datasets in Seaborn:")
print(datasets)

# Load multiple datasets
df_tips = sns.load_dataset('tips')
df_flights = sns.load_dataset('flights')
df_titanic = sns.load_dataset('titanic')
df_penguins = sns.load_dataset('penguins')
# Out:
# Available datasets in Seaborn:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ### Step 2 Initial Data Inspection

# %%
print(df.head(10))
print(df.shape)
print(df.dtypes)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa
# (150, 5)
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
for df, name in zip([df_tips, df_flights, df_titanic, df_penguins], 
                    ['Tips', 'Flights', 'Titanic', 'Penguins']):
    print(f"\n{name} Dataset:\n")
    print(df.head(10))
    print("Shape:", df.shape)
    print("Data Types:\n", df.dtypes)
# Out:
# Tips Dataset:
#
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
# Shape: (244, 7)
# Data Types:
#  total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
#
# Flights Dataset:
#
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# ...

# %% [markdown]
# ### Step 3 Initial Descriptive Statistics

# %%
print(df.describe())
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
for df, name in zip([df_tips, df_flights, df_titanic, df_penguins], 
                    ['Tips', 'Flights', 'Titanic', 'Penguins']):
    print(f"\n{name} Dataset Descriptive Statistics:\n")
    print(df.describe())
# Out:
# Tips Dataset Descriptive Statistics:
#
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
#
# Flights Dataset Descriptive Statistics:
#
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000
#
# Titanic Dataset Descriptive Statistics:
#
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# ...

# %% [markdown]
# ### Step 4: Step 4. Initial Data Distribution for Numerical Columns

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the Iris dataset
df = sns.load_dataset('iris')

# Inspect the first few rows
print(df.head())

# Print column names to verify
print(df.columns)

# Plotting histogram for 'sepal_length' if it exists
if 'sepal_length' in df.columns:
    df['sepal_length'].hist()
    plt.title('Histogram of Sepal Length')
    plt.xlabel('Sepal Length')
    plt.ylabel('Frequency')
    plt.show()
else:
    print("'sepal_length' column not found in the dataset")

# Plotting histograms for all numerical columns
df.hist()
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

for df, name in zip([df_tips, df_flights, df_titanic, df_penguins], 
                    ['Tips', 'Flights', 'Titanic', 'Penguins']):
    print(f"\n{name} Dataset Histograms:\n")
    df.hist(figsize=(10, 8))
    plt.suptitle(f'{name} Dataset - Histograms')
    plt.show()
# Out:
# Tips Dataset Histograms:
# Flights Dataset Histograms:
# Titanic Dataset Histograms:
# Penguins Dataset Histograms:

# %% [markdown]
# ### Observations:

# %% [markdown]
# ### Step 5: Initial Data Distribution for Categorical Columns

# %%
# Inspect value counts by categorical column
df['species'].value_counts()

# Inspect value counts for all categorical columns
for col in df.select_dtypes(include=['object', 'category']).columns:
    # Display count plot
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# Show all plots
plt.show()

# %%
import seaborn as sns

for df, name in zip([df_tips, df_flights, df_titanic, df_penguins], 
                    ['Tips', 'Flights', 'Titanic', 'Penguins']):
    print(f"\n{name} Dataset Categorical Value Counts:\n")
    for col in df.select_dtypes(include=['object', 'category']).columns:
        print(f"{col}:\n{df[col].value_counts()}\n")
        sns.countplot(x=col, data=df)
        plt.title(f'Distribution of {col} in {name} Dataset')
        plt.show()
# Out:
# Tips Dataset Categorical Value Counts:
#
# sex:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64
# smoker:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64
# day:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64
# time:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64
# Flights Dataset Categorical Value Counts:
#
# month:
# month
# Jan    12
# Feb    12
# Mar    12
# Apr    12
# May    12
# Jun    12
# Jul    12
# Aug    12
# Sep    12
# Oct    12
# Nov    12
# Dec    12
# Name: count, dtype: int64
# Titanic Dataset Categorical Value Counts:
#
# sex:
# sex
# male      577
# female    314
# Name: count, dtype: int64
# embarked:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
# class:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64
# who:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64
# deck:
# deck
# C    59
# ...

# %% [markdown]
# ### Step 6: Initial Data Transformation and Feature Engineering
#
# Use pandas and other tools to perform transformations as needed. Transformation may include renaming columns, adding new columns, or transforming existing data for more in-depth analysis.

# %%
print(df.columns)
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
#Rename Columns
df.rename(columns={'body_mass_g': 'Body Mass in grams'}, inplace=True)

#create new columns
df['Bill Area'] = df['bill_length_mm'] * df['bill_depth_mm']

#convert numerical features into bins for analysis
df['Body Mass in grams'] = pd.cut(df['Body Mass in grams'], bins=5, labels=['Shorter', 'Short', 'Medium', 'Long','Longer'])

# %%
df_tips['tip_percentage'] = df_tips['tip'] / df_tips['total_bill'] * 100
df_flights['year'] = df_flights['year'].astype(str)
df_titanic['family_size'] = df_titanic['sibsp'] + df_titanic['parch'] + 1
df_penguins['bill_area'] = df_penguins['bill_length_mm'] * df_penguins['bill_depth_mm']

# %% [markdown]
# ### Step 7: Initial Visualizations
# Create a variety of chart types using seaborn and matplotlib to showcase different aspects of the data. There is a guided example in the resources section at the end of this document.

# %%
sns.pairplot(df, hue='species')
plt.show()

# %%
sns.pairplot(df_tips, hue='sex')
plt.show()

sns.lineplot(data=df_flights, x='year', y='passengers', hue='month')
plt.show()

sns.histplot(data=df_titanic, x='age', hue='survived', multiple='stack')
plt.show()

sns.scatterplot(data=df_penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')
plt.show()

# %% [markdown]
# ### Example

# %%
# Load the Iris dataset from Seaborn
iris = sns.load_dataset('iris')

# Data preprocessing
# Separate features and target variable
X = iris.drop('species', axis=1)
y = iris['species']

# Data processing
# Perform any necessary data processing steps here

# Data analysis
# Calculate summary statistics
summary_stats = X.describe()
print("Summary Statistics:")
print(summary_stats)

# Plot the graph using Seaborn and Matplotlib
sns.set(style="ticks")
sns.pairplot(iris, hue="species")
plt.show()
# Out:
# Summary Statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Exploratory Data Analysis of Multiple Datasets
#
# ### Tips Dataset
# - **Observations**: The tips dataset provides insights into tipping behavior, with histograms showing the distribution of total bills and tips.
# - **Insights**: Higher total bills generally result in higher tips, but the tip percentage varies significantly.
#
# ### Flights Dataset
# - **Observations**: Monthly passenger counts show seasonal trends, with peaks during summer months.
# - **Insights**: The number of passengers has generally increased over the decade, with noticeable dips in certain years.
#
# ### Titanic Dataset
# - **Observations**: The distribution of ages and survival rates reveal patterns in survival based on age and class.
# - **Insights**: Younger passengers and those in higher classes had higher survival rates.
#
# ### Penguins Dataset
# - **Observations**: Measurements of penguin bill dimensions show clear differences between species.
# - **Insights**: Bill length and depth can be used to distinguish between penguin species.
#
# ## Conclusion
# This analysis highlights the diversity of data available in Seaborn and the power of EDA in uncovering patterns and insights in different datasets.
